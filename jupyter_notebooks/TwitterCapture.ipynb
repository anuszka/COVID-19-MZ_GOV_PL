# %%
""" 
Author: Anna Ochab-Marcinek 
ochab@ichf.edu.pl
http://groups.ichf.edu.pl/ochab

Tested on: 
Python 3.6.10 :: Anaconda, Inc.
jupyter-notebook 6.0.3

"""
# Out:
# ' \nAuthor: Anna Ochab-Marcinek \nochab@ichf.edu.pl\nhttp://groups.ichf.edu.pl/ochab\n\nTested on: \nPython 3.6.10 :: Anaconda, Inc.\njupyter-notebook 6.0.3\n\n'

# %%
exec(open('../code/TwitterCaptureMZ_GOV_PL.py').read())
# Out:
# ---------------------------------------------------------------
# Getting tweets from MZ_GOV_PL ...
#
# ---------------------------------------------------------------
# Last local data file found: ../data/cor.2020.04.15.csv
#        Data  Dzień  Wykryci zakażeni     Testy  Hospitalizowani  Zmarli  \
# 40  4/10/20   37.0            5955.0  118295.0           2409.0   181.0
# 41  4/11/20   38.0            6356.0  129560.0           2426.0   208.0
# 42  4/12/20   39.0            6674.0  138007.0           2481.0   232.0
# 43  4/13/20   40.0            6934.0  143630.0           2510.0   245.0
# 44  4/14/20   41.0            7202.0  148321.0           2471.0   263.0
#
#     Kwarantanna   Nadzór  Testy, wartości przybliżone  \
# 40     158663.0  33879.0                  NaN
# 41     166973.0  31370.0                  NaN
# 42     162974.0  30982.0                  NaN
# 43     151548.0  29571.0                  NaN
# 44     144875.0  28665.0                  NaN
#
# ...

# %%
exec(open('../code/TwitterCaptureImagesTestedMZ_GOV_PL.py').read())
# Out:
# ---------------------------------------------------------------
# Getting tweets from MZ_GOV_PL ...
#
# ---------------------------------------------------------------
# Last local data file found: ../data/cor.2020.04.15.csv
#        Data  Dzień  Wykryci zakażeni     Testy  Hospitalizowani  Zmarli  \
# 40  4/10/20   37.0            5955.0  118295.0           2409.0   181.0
# 41  4/11/20   38.0            6356.0  129560.0           2426.0   208.0
# 42  4/12/20   39.0            6674.0  138007.0           2481.0   232.0
# 43  4/13/20   40.0            6934.0  143630.0           2510.0   245.0
# 44  4/14/20   41.0            7202.0  148321.0           2471.0   263.0
#
#     Kwarantanna   Nadzór  Testy, wartości przybliżone  \
# 40     158663.0  33879.0                  NaN
# 41     166973.0  31370.0                  NaN
# 42     162974.0  30982.0                  NaN
# 43     151548.0  29571.0                  NaN
# 44     144875.0  28665.0                  NaN
#
# ...

# %%
exec(open('../code/TwitterCaptureImagesHQSR-MZ_GOV_PL.py').read())
# Out:
# ---------------------------------------------------------------
# Getting tweets from MZ_GOV_PL ...
#
# ---------------------------------------------------------------
# Last local data file found: ../data/cor.2020.04.15.csv
#        Data  Dzień  Wykryci zakażeni     Testy  Hospitalizowani  Zmarli  \
# 40  4/10/20   37.0            5955.0  118295.0           2409.0   181.0
# 41  4/11/20   38.0            6356.0  129560.0           2426.0   208.0
# 42  4/12/20   39.0            6674.0  138007.0           2481.0   232.0
# 43  4/13/20   40.0            6934.0  143630.0           2510.0   245.0
# 44  4/14/20   41.0            7202.0  148321.0           2471.0   263.0
#
#     Kwarantanna   Nadzór  Testy, wartości przybliżone  \
# 40     158663.0  33879.0                  NaN
# 41     166973.0  31370.0                  NaN
# 42     162974.0  30982.0                  NaN
# 43     151548.0  29571.0                  NaN
# 44     144875.0  28665.0                  NaN
#
# ...
